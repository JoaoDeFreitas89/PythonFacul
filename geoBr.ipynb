# %%
# !pip install geopandas -q
# !pip install geobr -q
# !pip install contextily -q

# %%
#IMPORT NAS BIBLIOTECA
import geopandas as gpd
import geobr
import contextily as cx
import matplotlib.pyplot as plt

import matplotlib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-37019c7ae275> in <cell line: 0>()
#       1 #IMPORT NAS BIBLIOTECA
#       2 import geopandas as gpd
# ----> 3 import geobr
#       4 import contextily as cx
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'geobr'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
geobr.list_geobr()
# Out:
# Function: read_country
# Geographies available: Country
# Years available: 1872, 1900, 1911, 1920, 1933, 1940, 1950, 1960, 1970, 1980, 1991, 2000, 2001, 2010, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020
# Source: IBGE
# ------------------------------
# Function: read_region
# Geographies available: Region
# Years available: 2000, 2001, 2010, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020
# Source: IBGE
# ------------------------------
# Function: read_state
# Geographies available: States
# Years available: 1872, 1900, 1911, 1920, 1933, 1940, 1950, 1960, 1970, 1980, 1991, 2000, 2001, 2010, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020
# Source: IBGE
# ------------------------------
# Function: read_meso_region
# Geographies available: Meso region
# Years available: 2000, 2001, 2010, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020
# Source: IBGE
# ------------------------------
# Function: read_micro_region
# Geographies available: Micro region
# ...

# %%
unidade_cons = geobr.read_conservation_units()

# %%
unidade_cons.head()
# Out:
#   code_conservation_unit                             name_conservation_unit  \
# 0                   2350  RESERVA PARTICULAR DO PATRIMÔNIO NATURAL BUGIO...
# 1                   3787  AREA DE PROTECAO AMBIENTAL DA BACIA DO CORREGO...
# 2                   3445     RESERVA PARTICULAR DO PATRIMÔNIO NATURAL PILAR
# 3                    145               PARQUE NACIONAL DA SERRA DA CAPIVARA
# 4                   1754                      FLORESTA ESTADUAL DO ARAGUAIA
#
#   id_wcm                                  category group government_level  \
# 0   None  Reserva Particular do Patrimônio Natural    US         estadual
# 1   None                Área de Proteção Ambiental    US        municipal
# 2   None  Reserva Particular do Patrimônio Natural    US         estadual
# 3     64                                    Parque    PI          federal
# 4   None                                  Floresta    US         estadual
#
# ...

# %%
# @title group

from matplotlib import pyplot as plt
import seaborn as sns
unidade_cons.groupby('group').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
lista = [1,2,3,4,5]

# %%
lista = [1]

# %%
unidade_cons.shape[0]
# Out:
# 1934

# %%
print(("O conjuto de dados possui", unidade_cons.shape[0], 'linhas'))
print(("O conjuto de dados possui", unidade_cons.shape[0], 'colunas'))
# Out:
# ('O conjuto de dados possui', 1934, 'linhas')
# ('O conjuto de dados possui', 1934, 'colunas')

# %%
type(unidade_cons)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
biomas = geobr.read_biomes()
biomas
# Out:
#          name_biome  code_biome    year  \
# 0          Amazônia         1.0  2019.0
# 1          Caatinga         2.0  2019.0
# 2           Cerrado         3.0  2019.0
# 3    Mata Atlântica         4.0  2019.0
# 4             Pampa         5.0  2019.0
# 5          Pantanal         6.0  2019.0
# 6  Sistema Costeiro         NaN  2019.0
#
#                                             geometry
# 0  MULTIPOLYGON (((-44.08515 -2.41669, -44.09068 ...
# 1  MULTIPOLYGON (((-41.7408 -2.80826, -41.73291 -...
# 2  MULTIPOLYGON (((-43.39009 -2.33937, -43.38741 ...
# 3  MULTIPOLYGON (((-48.70814 -28.44851, -48.71072...
# 4  MULTIPOLYGON (((-52.82472 -27.46295, -52.80293...
# 5  MULTIPOLYGON (((-57.75946 -15.72779, -57.75659...
# 6  MULTIPOLYGON (((-44.64799 -2.87038, -44.65184 ...

# %%
# @title name_biome

from matplotlib import pyplot as plt
import seaborn as sns
biomas.groupby('name_biome').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# # Nova seção

# %%
biomas_2019 = geobr.read_biomes(year=2019)
biomas_2019
# Out:
#          name_biome  code_biome    year  \
# 0          Amazônia         1.0  2019.0
# 1          Caatinga         2.0  2019.0
# 2           Cerrado         3.0  2019.0
# 3    Mata Atlântica         4.0  2019.0
# 4             Pampa         5.0  2019.0
# 5          Pantanal         6.0  2019.0
# 6  Sistema Costeiro         NaN  2019.0
#
#                                             geometry
# 0  MULTIPOLYGON (((-44.08515 -2.41669, -44.09068 ...
# 1  MULTIPOLYGON (((-41.7408 -2.80826, -41.73291 -...
# 2  MULTIPOLYGON (((-43.39009 -2.33937, -43.38741 ...
# 3  MULTIPOLYGON (((-48.70814 -28.44851, -48.71072...
# 4  MULTIPOLYGON (((-52.82472 -27.46295, -52.80293...
# 5  MULTIPOLYGON (((-57.75946 -15.72779, -57.75659...
# 6  MULTIPOLYGON (((-44.64799 -2.87038, -44.65184 ...

# %%
import plotly.express as px
import geopandas as gpd
import geobr

# Baixar os biomas de 2019
biomas_2019 = geobr.read_biomes(year=2019)


import plotly.express as px
import geopandas as gpd
import geobr

# Baixar os biomas de 2019
biomas_2019 = geobr.read_biomes(year=2019)

# Converter para GeoJSON (necessário para Plotly)
biomas_geojson = biomas_2019.to_crs(epsg=4326).to_json()

# Criar o mapa 3D usando Plotly
fig = px.choropleth_mapbox(
    geojson=biomas_geojson,
    locations=biomas_2019.index,
    color=biomas_2019['name_biome'],
    color_discrete_sequence=px.colors.qualitative.G10, # or another valid color sequence
    mapbox_style="carto-positron",
    zoom=3,
    center={"lat": -14.2, "lon": -51.9},
    opacity=0.5,
    labels={'name_biome':'Bioma'}
)
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
```
import geopandas as gpd
import geobr

# Baixar os biomas de 2019
biomas_2019 = geobr.read_biomes(year=2019)

# Converter para GeoJSON (necessário para Plotly)
biomas_geojson = biomas_2019.to_crs(epsg=4326).to_json()

# Criar o mapa 3D usando Plotly
fig = px.choropleth_mapbox(
    geojson=biomas_geojson,
    locations=biomas_2019.index,
    color=biomas_2019['name_biome'],
    color_discrete_sequence=px.colors.qualitative.G10, # or another valid color sequence
    mapbox_style="carto-positron",
    zoom=3,
    center={"lat": -14.2, "lon": -51.9},
    opacity=0.5,
    labels={'name_biome':'Bioma'}
)
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
import geobr

# Baixar os biomas de 2019
biomas_2019 = geobr.read_biomes(year=2019)

# Converter para GeoJSON (necessário para Plotly)
biomas_geojson = biomas_2019.to_crs(epsg=4326).to_json()

# Criar o mapa 3D usando Plotly
fig = px.choropleth_mapbox(
    geojson=biomas_geojson,
    locations=biomas_2019.index,
    color=biomas_2019['name_biome'],
    color_discrete_sequence=px.colors.qualitative.G10, # or another valid color sequence
    mapbox_style="carto-positron",
    zoom=3,
    center={"lat": -14.2, "lon": -51.9},
    opacity=0.5,
    labels={'name_biome':'Bioma'}
)
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
```
import geopandas as gpd
import geobr

# Baixar os biomas de 2019
biomas_2019 = geobr.read_biomes(year=2019)

# Converter para GeoJSON (necessário para Plotly)
biomas_geojson = biomas_2019.to_crs(epsg=4326).to_json()

# Criar o mapa 3D usando Plotly
fig = px.choropleth_mapbox(
    geojson=biomas_geojson,
    locations=biomas_2019.index,
    color=biomas_2019['name_biome'],
    color_discrete_sequence=px.colors.qualitative.G10, # or another valid color sequence
    mapbox_style="carto-positron",
    zoom=3,
    center={"lat": -14.2, "lon": -51.9},
    opacity=0.5,
    labels={'name_biome':'Bioma'}
)
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
#   File "<ipython-input-4-76e714036834>", line 33
#     ```
#     ^
# SyntaxError: invalid syntax
